# %%
# %matplotlib nbagg
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import scipy as sp
from scipy.fftpack import fft,fftfreq,ifft

# %%
df = pd.read_csv("Sample-Data/28A18305A90B_20180315175916.csv",skiprows=5)
df
# Out:
#        //ARTIFACT    NUM                    DATE  ACC_X  ACC_Y  ACC_Z  EOG_L1  \
# 0             NaN      1  2018/03/15 17:59:16.13   -380   2276 -16281     138
# 1             NaN      2  2018/03/15 17:59:16.15   -391   2195 -16210      48
# 2             NaN      3  2018/03/15 17:59:16.17   -357   2205 -16157     -35
# 3             NaN      4  2018/03/15 17:59:16.19   -372   2304 -16237      -3
# 4             NaN      5  2018/03/15 17:59:16.21   -309   2317 -16326     113
# ...           ...    ...                     ...    ...    ...    ...     ...
# 13271         NaN  13272  2018/03/15 18:03:41.55 -13569  -9924  -1821     -42
# 13272         NaN  13273  2018/03/15 18:03:41.57 -13568  -9772  -2391     -26
# 13273         NaN  13274  2018/03/15 18:03:41.59 -14104  -9757  -1642     -81
# 13274         NaN  13275  2018/03/15 18:03:41.61 -14243  -9949  -1567     -63
# 13275         NaN  13276  2018/03/15 18:03:41.63 -13282  -9573  -2436     -40
#
# ...

# %%
df.dtypes
# Out:
# //ARTIFACT    float64
# NUM             int64
# DATE           object
# ACC_X           int64
# ACC_Y           int64
# ACC_Z           int64
# EOG_L1          int64
# EOG_R1          int64
# EOG_L2          int64
# EOG_R2          int64
# EOG_H1          int64
# EOG_H2          int64
# EOG_V1          int64
# EOG_V2          int64
# dtype: object

# %%
df["DATE"] = pd.to_datetime(df["DATE"])
df.drop(['//ARTIFACT','NUM'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                      DATE  ACC_X  ACC_Y  ACC_Z  EOG_L1  EOG_R1  EOG_L2  \
# 0 2018-03-15 17:59:16.130   -380   2276 -16281     138     170     -11
# 1 2018-03-15 17:59:16.150   -391   2195 -16210      48      73     114
# 2 2018-03-15 17:59:16.170   -357   2205 -16157     -35      -8     142
# 3 2018-03-15 17:59:16.190   -372   2304 -16237      -3      28      37
# 4 2018-03-15 17:59:16.210   -309   2317 -16326     113     150     -44
#
#    EOG_R2  EOG_H1  EOG_H2  EOG_V1  EOG_V2
# 0      20     -32     -31    -154      -4
# 1     145     -25     -31     -60    -129
# 2     172     -27     -30      21    -157
# 3      62     -31     -25     -12     -49
# 4     -15     -37     -29    -131      29

# %%
df.set_index("DATE",inplace=True)

# %%
df.head()
# Out:
#                          ACC_X  ACC_Y  ACC_Z  EOG_L1  EOG_R1  EOG_L2  EOG_R2  \
# DATE
# 2018-03-15 17:59:16.130   -380   2276 -16281     138     170     -11      20
# 2018-03-15 17:59:16.150   -391   2195 -16210      48      73     114     145
# 2018-03-15 17:59:16.170   -357   2205 -16157     -35      -8     142     172
# 2018-03-15 17:59:16.190   -372   2304 -16237      -3      28      37      62
# 2018-03-15 17:59:16.210   -309   2317 -16326     113     150     -44     -15
#
#                          EOG_H1  EOG_H2  EOG_V1  EOG_V2
# DATE
# 2018-03-15 17:59:16.130     -32     -31    -154      -4
# 2018-03-15 17:59:16.150     -25     -31     -60    -129
# 2018-03-15 17:59:16.170     -27     -30      21    -157
# 2018-03-15 17:59:16.190     -31     -25     -12     -49
# 2018-03-15 17:59:16.210     -37     -29    -131      29

# %%
len(df)
# Out:
# 13276

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["ACC_X"])
plt.plot(df.index,df["ACC_Y"])
plt.plot(df.index,df["ACC_Z"])
plt.grid()
plt.xlabel('time(second)')
plt.legend(['ACC_X','ACC_Y','ACC_Z'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["EOG_L1"])
plt.plot(df.index,df["EOG_L2"])
# plt.plot(data.Time,data.ACC_Z)
plt.grid()
plt.xlabel('time(second)')
plt.legend(['EOG_L1','EOG_L2'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["EOG_R1"])
plt.plot(df.index,df["EOG_R2"])
# plt.plot(data.Time,data.ACC_Z)
plt.grid()
plt.xlabel('time(second)')
plt.legend(['EOG_R1','EOG_R2'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["EOG_H1"])
plt.plot(df.index,df["EOG_H2"])
# plt.plot(data.Time,data.ACC_Z)
plt.grid()
plt.xlabel('time(second)')
plt.legend(['EOG_H1','EOG_H2'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["EOG_V1"])
plt.plot(df.index,df["EOG_V2"])
# plt.plot(data.Time,data.ACC_Z)
plt.grid()
plt.xlabel('time(second)')
plt.legend(['EOG_V1','EOG_V2'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fft_EOG_V1 = fft(df["EOG_V1"])
fft_EOG_V2 = fft(df["EOG_V2"])
psd_EOG_V1 = np.abs(fft_EOG_V1)**2
psd_EOG_V2 = np.abs(fft_EOG_V2)**2

# %%
d = (df.index[1]-df.index[0])
print(d)
d = float((d.microseconds)/10**6)
d
# Out:
# 0 days 00:00:00.020000
# 0.02

# %%
fft_freq = fftfreq(len(df),d=d)

# %%
i = fft_freq > 0

# %%
plt.figure(figsize=(10,5))
plt.plot(fft_freq[i],10*np.log10(psd_EOG_V1[i]))
# plt.plot(fft_freq,fft_EOG_V2)
# plt.plot(data.Time,data.ACC_Z)
plt.grid()
plt.xlabel('Frequency')
plt.ylabel('PSD (dB)')
plt.legend(['EOG_V1','EOG_V2'],loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
psd_EOG_V1_p = 10*np.log10(psd_EOG_V1[i])# p - positive axis
fft_freq_p = fft_freq[i]

# %%
psd_EOG_V1_n = fft_freq_p[psd_EOG_V1_p ==np.max(psd_EOG_V1_p)] # n - noise

# %%
temp_fft_EOG_V1 = fft_EOG_V1.copy()
temp_fft_EOG_V1[np.abs(fft_freq)>psd_EOG_V1_n]=0

# %%
t_EOG_V1 = np.real(ifft(temp_fft_EOG_V1))

# %%
len(t_EOG_V1)
# Out:
# 13276

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df["EOG_V1"])
plt.plot(df.index,t_EOG_V1)
plt.legend(['EOG_V1','clean_EOG_V1'],loc='upper right')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
