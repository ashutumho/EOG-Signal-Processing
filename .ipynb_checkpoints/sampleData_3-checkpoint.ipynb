# %%
# %matplotlib nbagg
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import scipy as sp
from scipy.fftpack import fft,fftfreq,ifft,rfft,rfftfreq,irfft

# %%
dataFile = "Sample-Data/28A18305A90B_20180315175916.csv"#r"Sample-Data/28A18305A90B_20180315175916.csv"
df = pd.read_csv(dataFile,skiprows=5)
df
# Out:
#        //ARTIFACT    NUM                    DATE  ACC_X  ACC_Y  ACC_Z  EOG_L1  \
# 0             NaN      1  2018/03/15 17:59:16.13   -380   2276 -16281     138
# 1             NaN      2  2018/03/15 17:59:16.15   -391   2195 -16210      48
# 2             NaN      3  2018/03/15 17:59:16.17   -357   2205 -16157     -35
# 3             NaN      4  2018/03/15 17:59:16.19   -372   2304 -16237      -3
# 4             NaN      5  2018/03/15 17:59:16.21   -309   2317 -16326     113
# ...           ...    ...                     ...    ...    ...    ...     ...
# 13271         NaN  13272  2018/03/15 18:03:41.55 -13569  -9924  -1821     -42
# 13272         NaN  13273  2018/03/15 18:03:41.57 -13568  -9772  -2391     -26
# 13273         NaN  13274  2018/03/15 18:03:41.59 -14104  -9757  -1642     -81
# 13274         NaN  13275  2018/03/15 18:03:41.61 -14243  -9949  -1567     -63
# 13275         NaN  13276  2018/03/15 18:03:41.63 -13282  -9573  -2436     -40
#
#        EOG_R1  EOG_L2  EOG_R2  EOG_H1  EOG_H2  EOG_V1  EOG_V2
# 0         170     -11      20     -32     -31    -154      -4
# 1          73     114     145     -25     -31     -60    -129
# 2          -8     142     172     -27     -30      21    -157
# 3          28      37      62     -31     -25     -12     -49
# 4         150     -44     -15     -37     -29    -131      29
# ...       ...     ...     ...     ...     ...     ...     ...
# 13271      25     -75      93     -67    -168       8      -9
# 13272      80     -40      92    -106    -132     -27     -26
# 13273     119     -21      54    -200     -75     -19     -16
# 13274      90     -31      61    -153     -92     -13     -15
# 13275      28     -68      43     -68    -111       6      12
#
# [13276 rows x 14 columns]

# %%
df.dtypes
# Out:
# //ARTIFACT    float64
# NUM             int64
# DATE           object
# ACC_X           int64
# ACC_Y           int64
# ACC_Z           int64
# EOG_L1          int64
# EOG_R1          int64
# EOG_L2          int64
# EOG_R2          int64
# EOG_H1          int64
# EOG_H2          int64
# EOG_V1          int64
# EOG_V2          int64
# dtype: object

# %%
df["DATE"] = pd.to_datetime(df["DATE"])
df.drop(['//ARTIFACT','NUM'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                      DATE  ACC_X  ACC_Y  ACC_Z  EOG_L1  EOG_R1  EOG_L2  \
# 0 2018-03-15 17:59:16.130   -380   2276 -16281     138     170     -11
# 1 2018-03-15 17:59:16.150   -391   2195 -16210      48      73     114
# 2 2018-03-15 17:59:16.170   -357   2205 -16157     -35      -8     142
# 3 2018-03-15 17:59:16.190   -372   2304 -16237      -3      28      37
# 4 2018-03-15 17:59:16.210   -309   2317 -16326     113     150     -44
#
#    EOG_R2  EOG_H1  EOG_H2  EOG_V1  EOG_V2
# 0      20     -32     -31    -154      -4
# 1     145     -25     -31     -60    -129
# 2     172     -27     -30      21    -157
# 3      62     -31     -25     -12     -49
# 4     -15     -37     -29    -131      29

# %%
df.set_index("DATE",inplace=True)

# %%
df.head()
# Out:
#                          ACC_X  ACC_Y  ACC_Z  EOG_L1  EOG_R1  EOG_L2  EOG_R2  \
# DATE
# 2018-03-15 17:59:16.130   -380   2276 -16281     138     170     -11      20
# 2018-03-15 17:59:16.150   -391   2195 -16210      48      73     114     145
# 2018-03-15 17:59:16.170   -357   2205 -16157     -35      -8     142     172
# 2018-03-15 17:59:16.190   -372   2304 -16237      -3      28      37      62
# 2018-03-15 17:59:16.210   -309   2317 -16326     113     150     -44     -15
#
#                          EOG_H1  EOG_H2  EOG_V1  EOG_V2
# DATE
# 2018-03-15 17:59:16.130     -32     -31    -154      -4
# 2018-03-15 17:59:16.150     -25     -31     -60    -129
# 2018-03-15 17:59:16.170     -27     -30      21    -157
# 2018-03-15 17:59:16.190     -31     -25     -12     -49
# 2018-03-15 17:59:16.210     -37     -29    -131      29

# %%
d = (df.index[1]-df.index[0])
print(d)
d = float((d.microseconds)/10**6)
d
# Out:
# 0 days 00:00:00.020000
# 0.02

# %%
#https://www.kaggle.com/theoviel/fast-fourier-transform-denoising
def filter_signal(signal, threshold=1e8):
    fourier = rfft(signal)
    frequencies = rfftfreq(signal.size, d=20e-3/len(signal))
    fourier[frequencies > threshold] = 0
    return irfft(fourier)

# %%
#https://ipython-books.github.io/101-analyzing-the-frequency-components-of-a-signal-with-a-fast-fourier-transform/
def applyfft(EOG_signal,d):
    fft_EOG_signal = fft(EOG_signal)
    psd_EOG_signal = np.abs(fft_EOG_signal)**2
    fft_freq = fftfreq(len(EOG_signal),d=d)
    i = fft_freq > 0
    psd_EOG_signal_p = 10*np.log10(psd_EOG_signal[i])# p - positive axis
    fft_freq_p = fft_freq[i]
    psd_EOG_signal_n = fft_freq_p[psd_EOG_signal_p ==np.max(psd_EOG_signal_p)] # n - noise 
    if np.where(psd_EOG_signal_p==np.amax(psd_EOG_signal_p))[0]:
        temp_fft_EOG_signal = fft_EOG_signal.copy()
        temp_fft_EOG_signal[np.abs(fft_freq)>psd_EOG_signal_n]=0
        t_EOG_signal = np.real(ifft(temp_fft_EOG_signal))        
        return t_EOG_signal
    else:
        return filter_signal(EOG_signal,1e5)

# %%
def applyPSDsignal(EOG_signal,d):
    fft_EOG_signal = fft(EOG_signal)
    psd_EOG_signal = np.abs(fft_EOG_signal)**2
    fft_freq = fftfreq(len(EOG_signal),d=d)
    i = fft_freq > 0
    psd_EOG_signal_p = 10*np.log10(psd_EOG_signal[i])# p - positive axis
    fft_freq_p = fft_freq[i]
    plt.figure(figsize=(10,5))
    plt.plot(fft_freq_p,psd_EOG_signal_p)
    plt.grid()
    plt.xlabel('Frequency')
    plt.ylabel('PSD (dB)')
    plt.legend(['EOG'],loc='upper right')
    plt.show()

# %%
def applyFFTsignal(EOG_signal,d):
    fft_EOG_signal = fft(EOG_signal)
    psd_EOG_signal = np.abs(fft_EOG_signal)**2
    fft_freq = fftfreq(len(EOG_signal),d=d)
    i = fft_freq > 0
#     psd_EOG_signal_p = 10*np.log10(psd_EOG_signal[i])# p - positive axis
    fft_EOG_signal_p = np.real(fft_EOG_signal[i])
    fft_freq_p = fft_freq[i]
    plt.figure(figsize=(10,5))
    plt.plot(fft_freq_p,fft_EOG_signal_p)
    plt.grid()
    plt.xlabel('Frequency')
    plt.ylabel('FFT')
    plt.legend(['EOG'],loc='upper right')
    plt.show()

# %%
# applyFFTsignal(df["ACC_X"],d)

# %%
filtered_df = pd.DataFrame()
for sgnl in df.columns:
#     print(sgnl)
    if filtered_df.empty:
        filtered_df["DATE"] = df.index
    
    filtered_df["fft_"+sgnl] = applyfft(df[sgnl],d)
filtered_df.set_index("DATE",inplace=True)
filtered_df.head()
# Out:
# 75%       47.000000    131.000000    -34.000000    -34.000000      4.000000
# max     2024.000000   1824.000000   4074.000000   4072.000000   2040.000000
#
#              EOG_V2
# count  13276.000000
# mean     -32.039997
# std      212.146189
# min    -1893.000000
# 25%      -80.000000
# 50%      -34.000000
# 75%        4.000000
# max     2040.000000

# %%
filtered_df.describe()
# Out:
#           fft_ACC_X     fft_ACC_Y     fft_ACC_Z    fft_EOG_L1    fft_EOG_R1  \
# count  13276.000000  13276.000000  13276.000000  13276.000000  13276.000000
# mean   -1468.331425   5603.081199 -14321.289319    -14.972130     79.423396
# std     2854.935665   3674.736348   3160.273734    248.567531    236.186775
# min   -24774.313210 -12697.695398 -23285.360129  -2427.117651  -2466.039011
# 25%    -2725.988446   2536.204379 -16189.445996    -49.249684     43.928866
# 50%     -470.075090   5653.967188 -15183.634423     -6.872843     89.210779
# 75%      105.140970   9135.607911 -13287.736223     42.654635    123.568316
# max     7680.037385  21552.253327  23060.532557   2443.053118   2250.955813
#
#          fft_EOG_L2    fft_EOG_R2    fft_EOG_H1    fft_EOG_H2    fft_EOG_V1  \
# count  13276.000000  13276.000000  13276.000000  13276.000000  13276.000000
# mean     -15.054610     79.367882    -94.395526    -94.422492    -32.107261
# std      248.375006    236.223562    261.217589    261.004893    206.402898
# min    -2444.013352  -2447.760334  -4203.674931  -4185.316703  -2132.343089
# 25%      -48.899637     43.864214   -152.954655   -153.153312    -75.488122
# 50%       -6.968932     88.811412    -90.552533    -90.919353    -37.692479
# 75%       42.339062    124.685521    -33.390424    -33.322868     -2.772454
# max     2459.124638   2260.032500   4305.550972   4383.768500   2456.763310
#
#          fft_EOG_V2
# count  13276.000000
# mean     -32.039997
# std      206.171801
# min    -2124.959648
# 25%      -75.422602
# 50%      -37.568022
# 75%       -2.230500
# max     2403.935696

# %%
for sgnl in df.columns:
    print("---------- "+sgnl+" ----------")
    print(np.corrcoef(filtered_df["fft_"+sgnl],df[sgnl]))
    print(" ")
# Out:
# ---------- ACC_X ----------
# [[1.        0.9566522]
#  [0.9566522 1.       ]]
#
# ---------- ACC_Y ----------
# [[1.         0.99535808]
#  [0.99535808 1.        ]]
#
# ---------- ACC_Z ----------
# [[1.         0.97964018]
#  [0.97964018 1.        ]]
#
# ---------- EOG_L1 ----------
# [[1.         0.94894059]
#  [0.94894059 1.        ]]
#
# ---------- EOG_R1 ----------
# [[1.         0.97539153]
#  [0.97539153 1.        ]]
#
# ---------- EOG_L2 ----------
# [[1.         0.94945734]
#  [0.94945734 1.        ]]
#
# ---------- EOG_R2 ----------
# [[1.         0.97488123]
#  [0.97488123 1.        ]]
#
# ---------- EOG_H1 ----------
# [[1.         0.95734627]
#  [0.95734627 1.        ]]
#
# ---------- EOG_H2 ----------
# [[1.         0.95878995]
#  [0.95878995 1.        ]]
#
# ---------- EOG_V1 ----------
# [[1.         0.97327987]
#  [0.97327987 1.        ]]
#
# ---------- EOG_V2 ----------
# [[1.         0.97183834]
#  [0.97183834 1.        ]]

# %%
nameFile = dataFile.split("/")[1]
nameFile = nameFile.split(".")[0]
nameFile
# Out:
# '28A18305A90B_20180315175916'

# %%
for sgnl in df.columns:
    plt.figure(figsize=(10, 5))
    plt.plot(df.index,df[sgnl],label = sgnl)
    plt.plot(df.index,filtered_df["fft_"+sgnl],label = "fft_"+sgnl)
    plt.grid()
    plt.xlabel('time(second)')
    plt.legend(loc='upper right')
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
